# %%
import yfinance as yf
import pandas as pd

# %%
ticker = yf.Ticker('AAPL')

# %%
ticker.options
# Out:
# ('2026-07-20',
#  '2026-07-22',
#  '2026-07-24',
#  '2026-07-27',
#  '2026-07-29',
#  '2026-07-31',
#  '2026-08-07',
#  '2026-08-14',
#  '2026-08-21',
#  '2026-08-28',
#  '2026-09-18',
#  '2026-10-16',
#  '2026-11-20',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-02-19',
#  '2027-03-19',
#  '2027-06-17',
#  '2027-09-17',
#  '2027-12-17',
#  '2028-01-21',
#  '2028-03-17',
#  '2028-12-15')

# %%
expiry = ticker.options[0]
expiry
# Out:
# '2026-07-20'

# %%
chain = ticker.option_chain(expiry)

# %%
type(chain)
# Out:
# yfinance.ticker.Options

# %%
chain.calls.head()
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0  AAPL260720C00215000 2026-07-14 18:50:30+00:00   215.0     100.19  116.70
# 1  AAPL260720C00220000 2026-07-14 18:50:30+00:00   220.0      95.22  111.75
# 2  AAPL260720C00225000 2026-07-14 18:50:54+00:00   225.0      90.25  106.65
# 3  AAPL260720C00230000 2026-07-16 15:08:36+00:00   230.0     100.22  101.75
# 4  AAPL260720C00235000 2026-07-06 15:57:48+00:00   235.0      79.00   96.75
#
#       ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0  120.70  0.000000       0.000000     NaN             1           3.125490
# 1  115.70  0.000000       0.000000     NaN             1           2.989260
# 2  110.50  0.000000       0.000000     2.0             0           2.788577
# 3  105.45  0.690002       0.693261    16.0            16           2.642582
# 4  100.45  0.000000       0.000000     NaN             0           2.516605
#
#    inTheMoney contractSize currency
# ...
